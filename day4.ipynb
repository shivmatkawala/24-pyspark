# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
import pandas as pd

# %%
spark = SparkSession.builder.appName("practice").getOrCreate()

# %%
list1 = [
    {"Name": "Krishna", "Age": 44, "Salary": 42000, "DOB": "22/11/2025"},
    {"Name": "Soumya", "Age": 39, "Salary": 43000, "DOB": "19/12/2025"},
    {"Name": "Naren", "Age": 38, "Salary": 48000, "DOB": "10/11/2025"},
    {"Name": "Mallesh", "Age": 32, "Salary": 42000, "DOB": "15/10/2025"},
    {"Name": "Poojitha", "Age": 34, "Salary": 40000, "DOB": "22/10/2025"},
    {"Name": "Priya", "Age": 30, "Salary": 50000, "DOB": "10/11/2025"},
    
]

df1 = spark.createDataFrame(list1)
# df1
# df1.show()
# df1.printSchema()
# df1.describe()
# df1.count()

# %%
# df1.schema
# df1.dtypes
# df1.columns

# %%
df2 = (
    spark.read
    .option("header", "false")
    .option("inferSchema", "true")
    .csv("dataFiles/sample.csv")
)

columnNames = ["ID", "Name", "Email", "Age", "City", "Department", "Salry", "DOB","isActive"]

df2 = df2.toDF(*columnNames)    # toDF Method is there to only rename columnsss
df2.show()
# Out:
# +---+-------------+--------------------+---+-------------+-----------+------+----------+--------+
# | ID|         Name|               Email|Age|         City| Department| Salry|       DOB|isActive|
# +---+-------------+--------------------+---+-------------+-----------+------+----------+--------+
# |  1|Alice Johnson|alice.johnson@exa...| 29|     New York|Engineering| 92000|2021-03-15|    true|
# |  2|    Bob Smith|bob.smith@example...| 34|San Francisco|  Marketing| 78000|2019-07-22|    true|
# |  3|  Carol White|carol.white@examp...| 41|      Chicago|    Finance|105000|2017-01-10|    true|
# |  4|  David Brown|david.brown@examp...| 26|       Austin|Engineering| 88000|2022-06-01|    true|
# |  5| Eva Martinez|eva.martinez@exam...| 38|        Miami|         HR| 67000|2018-11-05|   false|
# |  6|    Frank Lee|frank.lee@example...| 45|      Seattle|Engineering|115000|2015-09-18|    true|
# |  7|    Grace Kim|grace.kim@example...| 31|       Boston|     Design| 82000|2020-04-27|    true|
# ...
